# %%
import pandas as pd
import numpy as np
import umap
import seaborn as sns
import matplotlib.pyplot as plt

# %%
output_gene_ranking_path = "data/out_gene_rankings_bc.csv"
df_apu_labels = pd.read_csv(output_gene_ranking_path, sep=" ", header=None)
df_apu_labels.columns = ["name", "out", "rank"]
df_apu_labels
# Out:
#                      name       out  rank
# 0         cg15694422_MGLL  1.137238     1
# 1        cg22644321_TRIB1  1.234473     1
# 2      cg26582754_PHACTR2  1.198782     1
# 3        cg20758823_RUNX2  1.240496     1
# 4       cg03688134_PLXNC1  1.240659     1
# ...                   ...       ...   ...
# 9625    cg18098750_TICAM2  0.840723     1
# 9626  cg21510680_VAV3-AS1  0.840723     1
# 9627      cg21510680_VAV3  0.840723     1
# 9628    cg16614500_TMEM80  0.840723     1
# 9629     cg16614500_DEAF1  0.840723     1
#
# [9630 rows x 3 columns]

# %%
APU_scores_df = df_apu_labels[["name", "out"]]
APU_scores_df
# Out:
#                      name       out
# 0         cg15694422_MGLL  1.137238
# 1        cg22644321_TRIB1  1.234473
# 2      cg26582754_PHACTR2  1.198782
# 3        cg20758823_RUNX2  1.240496
# 4       cg03688134_PLXNC1  1.240659
# ...                   ...       ...
# 9625    cg18098750_TICAM2  0.840723
# 9626  cg21510680_VAV3-AS1  0.840723
# 9627      cg21510680_VAV3  0.840723
# 9628    cg16614500_TMEM80  0.840723
# 9629     cg16614500_DEAF1  0.840723
#
# [9630 rows x 2 columns]

# %%
df_seeds = pd.read_csv("data/seed_features_bc.csv", sep="\t", header=None)
train_seeds_list = df_seeds.iloc[:, 0].tolist()
len(train_seeds_list)
# Out:
# 197

# %%
APU_scores_df_not_seeds = APU_scores_df[~APU_scores_df['name'].isin(train_seeds_list)]
APU_scores_df_not_seeds.shape
# Out:
# (9449, 2)

# %%
APU_scores_df_not_seeds = APU_scores_df_not_seeds.sort_values(by = "out", ascending = False)
APU_scores_df_not_seeds
# Out:
#                       name       out
# 2665       cg26818637_NFIA  8.967411
# 1442     cg10165760_ZNF622  8.967403
# 690       cg18246521_PLCB1  8.967399
# 1084       cg12152073_FLNB  8.967357
# 2186     cg10053235_RAD51B  8.967345
# ...                    ...       ...
# 9445    cg20790496_BCL2L13  0.041445
# 9326  cg05216211_MIR1185-1  0.041444
# 9515        cg22504837_VCL  0.041415
# 9501     cg00380720_SGK223  0.041171
# 9303       cg00901138_CHN2  0.041128
#
# [9449 rows x 2 columns]

# %%
pseudo_labels = pd.qcut(x = APU_scores_df_not_seeds["out"], q = 4, labels = ["RN", "LN", "WN", "LP"])
print(pseudo_labels)
APU_scores_df_not_seeds["label"] = pseudo_labels
APU_scores_seeds = APU_scores_df[APU_scores_df['name'].isin(train_seeds_list)]
APU_scores_seeds["label"] = "P"
APU_scores_seeds
# Out:
# 2665    LP
# 1442    LP
# 690     LP
# 1084    LP
# 2186    LP
#         ..
# 9445    RN
# 9326    RN
# 9515    RN
# 9501    RN
# 9303    RN
# Name: out, Length: 9449, dtype: category
# Categories (4, object): ['RN' < 'LN' < 'WN' < 'LP']
# /tmp/ipykernel_1741382/1479929415.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   APU_scores_seeds["label"] = "P"
#                            name       out label
# 0               cg15694422_MGLL  1.137238     P
# 1              cg22644321_TRIB1  1.234473     P
# 2            cg26582754_PHACTR2  1.198782     P
# 3              cg20758823_RUNX2  1.240496     P
# 4             cg03688134_PLXNC1  1.240659     P
# ...                         ...       ...   ...
# 8732          cg06713675_EXOSC9  0.840723     P
# 8733          cg05635388_EXOSC9  0.840723     P
# 8734  cg05332652_TCONS_00029157  0.840723     P
# 8735  cg02409829_TCONS_00029157  0.840723     P
# 8736           cg26371957_NINJ2  1.086158     P
#
# [181 rows x 3 columns]

# %%
genes_labels_df = pd.concat([APU_scores_seeds, APU_scores_df_not_seeds])
genes_labels_df['name'] = genes_labels_df['name'].astype(str)
genes_labels_df
# Out:
#                       name       out label
# 0          cg15694422_MGLL  1.137238     P
# 1         cg22644321_TRIB1  1.234473     P
# 2       cg26582754_PHACTR2  1.198782     P
# 3         cg20758823_RUNX2  1.240496     P
# 4        cg03688134_PLXNC1  1.240659     P
# ...                    ...       ...   ...
# 9445    cg20790496_BCL2L13  0.041445    RN
# 9326  cg05216211_MIR1185-1  0.041444    RN
# 9515        cg22504837_VCL  0.041415    RN
# 9501     cg00380720_SGK223  0.041171    RN
# 9303       cg00901138_CHN2  0.041128    RN
#
# [9630 rows x 3 columns]

# %%
nedbit_path = "data/nedbit_features_bc.csv"
gene_features_df = pd.read_csv(nedbit_path, sep=",")
gene_features_df
# Out:
#                      name  class  degree  ring   NetRank       NetShort  \
# 0         cg15694422_MGLL      1     492     1  0.853574   5.179237e+02
# 1        cg22644321_TRIB1      1    3272     1  0.903701   5.830698e+02
# 2      cg26582754_PHACTR2      1    1440     1  0.886602   5.269176e+02
# 3        cg20758823_RUNX2      1    3220     1  0.906007   5.639762e+02
# 4       cg03688134_PLXNC1      1    3119     1  0.905790   5.622860e+02
# ...                   ...    ...     ...   ...       ...            ...
# 9625    cg18098750_TICAM2    -99       1     0  0.000000  5.356309e-305
# 9626  cg21510680_VAV3-AS1    -99       1     0  0.000000  5.356309e-305
# 9627      cg21510680_VAV3    -99       1     0  0.000000  5.356309e-305
# 9628    cg16614500_TMEM80    -99       1     0  0.000000  5.356309e-305
# 9629     cg16614500_DEAF1    -99       1     0  0.000000  5.356309e-305
#
#       HeatDiff  InfoDiff
# 0     1.085045  0.129803
# 1     0.729632  0.016267
# 2     0.849829  0.017671
# 3     0.703557  0.016218
# 4     0.704444  0.016267
# ...        ...       ...
# 9625  0.000000  0.000000
# 9626  0.000000  0.000000
# 9627  0.000000  0.000000
# 9628  0.000000  0.000000
# 9629  0.000000  0.000000
#
# [9630 rows x 8 columns]

# %%
features_and_labels_df = gene_features_df.merge(genes_labels_df, on = "name")
features_and_labels_df["label"] = features_and_labels_df["label"].map({"P": 0, "LP": 1, "WN": 2, "LN":3, "RN":4})
features_and_labels_df["label_binary"] = features_and_labels_df["label"].map({0: 0, 1: 1, 2: 1, 3:1, 4:1})
features_and_labels_df.pop("class") #removing class attribute
features_and_labels_df.pop("out")
features_and_labels_df
# Out:
#                      name  degree  ring   NetRank       NetShort  HeatDiff  \
# 0         cg15694422_MGLL     492     1  0.853574   5.179237e+02  1.085045
# 1        cg22644321_TRIB1    3272     1  0.903701   5.830698e+02  0.729632
# 2      cg26582754_PHACTR2    1440     1  0.886602   5.269176e+02  0.849829
# 3        cg20758823_RUNX2    3220     1  0.906007   5.639762e+02  0.703557
# 4       cg03688134_PLXNC1    3119     1  0.905790   5.622860e+02  0.704444
# ...                   ...     ...   ...       ...            ...       ...
# 9625    cg18098750_TICAM2       1     0  0.000000  5.356309e-305  0.000000
# 9626  cg21510680_VAV3-AS1       1     0  0.000000  5.356309e-305  0.000000
# 9627      cg21510680_VAV3       1     0  0.000000  5.356309e-305  0.000000
# 9628    cg16614500_TMEM80       1     0  0.000000  5.356309e-305  0.000000
# 9629     cg16614500_DEAF1       1     0  0.000000  5.356309e-305  0.000000
#
#       InfoDiff  label  label_binary
# 0     0.129803      0             0
# 1     0.016267      0             0
# 2     0.017671      0             0
# 3     0.016218      0             0
# 4     0.016267      0             0
# ...        ...    ...           ...
# 9625  0.000000      1             1
# 9626  0.000000      1             1
# 9627  0.000000      1             1
# 9628  0.000000      1             1
# 9629  0.000000      1             1
#
# [9630 rows x 9 columns]

# %%
nebit_features = features_and_labels_df.iloc[:, 2:7]
nebit_features
# Out:
#       ring   NetRank       NetShort  HeatDiff  InfoDiff
# 0        1  0.853574   5.179237e+02  1.085045  0.129803
# 1        1  0.903701   5.830698e+02  0.729632  0.016267
# 2        1  0.886602   5.269176e+02  0.849829  0.017671
# 3        1  0.906007   5.639762e+02  0.703557  0.016218
# 4        1  0.905790   5.622860e+02  0.704444  0.016267
# ...    ...       ...            ...       ...       ...
# 9625     0  0.000000  5.356309e-305  0.000000  0.000000
# 9626     0  0.000000  5.356309e-305  0.000000  0.000000
# 9627     0  0.000000  5.356309e-305  0.000000  0.000000
# 9628     0  0.000000  5.356309e-305  0.000000  0.000000
# 9629     0  0.000000  5.356309e-305  0.000000  0.000000
#
# [9630 rows x 5 columns]

# %%
# normalise NetShort feature

from sklearn.preprocessing import normalize, RobustScaler

netshort = np.array(nebit_features["NetShort"].tolist())
netshort = netshort.reshape(-1, 1)
print(len(netshort), netshort.shape)
transformer = RobustScaler().fit(netshort)
#norm_netshort = normalize(netshort, norm="l2")
norm_netshort = transformer.transform(netshort)
norm_netshort
# Out:
# 9630 (9630, 1)
# array([[ 0.82578344],
#        [ 1.19652862],
#        [ 0.87696755],
#        ...,
#        [-2.12171015],
#        [-2.12171015],
#        [-2.12171015]])

# %%
nebit_features["NetShort"] = norm_netshort
nebit_features
# Out:
#       ring   NetRank  NetShort  HeatDiff  InfoDiff
# 0        1  0.853574  0.825783  1.085045  0.129803
# 1        1  0.903701  1.196529  0.729632  0.016267
# 2        1  0.886602  0.876968  0.849829  0.017671
# 3        1  0.906007  1.087867  0.703557  0.016218
# 4        1  0.905790  1.078248  0.704444  0.016267
# ...    ...       ...       ...       ...       ...
# 9625     0  0.000000 -2.121710  0.000000  0.000000
# 9626     0  0.000000 -2.121710  0.000000  0.000000
# 9627     0  0.000000 -2.121710  0.000000  0.000000
# 9628     0  0.000000 -2.121710  0.000000  0.000000
# 9629     0  0.000000 -2.121710  0.000000  0.000000
#
# [9630 rows x 5 columns]

# %%
features_and_labels_df
# Out:
#                      name  degree  ring   NetRank       NetShort  HeatDiff  \
# 0         cg15694422_MGLL     492     1  0.853574   5.179237e+02  1.085045
# 1        cg22644321_TRIB1    3272     1  0.903701   5.830698e+02  0.729632
# 2      cg26582754_PHACTR2    1440     1  0.886602   5.269176e+02  0.849829
# 3        cg20758823_RUNX2    3220     1  0.906007   5.639762e+02  0.703557
# 4       cg03688134_PLXNC1    3119     1  0.905790   5.622860e+02  0.704444
# ...                   ...     ...   ...       ...            ...       ...
# 9625    cg18098750_TICAM2       1     0  0.000000  5.356309e-305  0.000000
# 9626  cg21510680_VAV3-AS1       1     0  0.000000  5.356309e-305  0.000000
# 9627      cg21510680_VAV3       1     0  0.000000  5.356309e-305  0.000000
# 9628    cg16614500_TMEM80       1     0  0.000000  5.356309e-305  0.000000
# 9629     cg16614500_DEAF1       1     0  0.000000  5.356309e-305  0.000000
#
#       InfoDiff  label  label_binary
# 0     0.129803      0             0
# 1     0.016267      0             0
# 2     0.017671      0             0
# 3     0.016218      0             0
# 4     0.016267      0             0
# ...        ...    ...           ...
# 9625  0.000000      1             1
# 9626  0.000000      1             1
# 9627  0.000000      1             1
# 9628  0.000000      1             1
# 9629  0.000000      1             1
#
# [9630 rows x 9 columns]

# %%
df_labels = features_and_labels_df[["name", "label"]]
df_labels
# Out:
#                      name  label
# 0         cg15694422_MGLL      0
# 1        cg22644321_TRIB1      0
# 2      cg26582754_PHACTR2      0
# 3        cg20758823_RUNX2      0
# 4       cg03688134_PLXNC1      0
# ...                   ...    ...
# 9625    cg18098750_TICAM2      1
# 9626  cg21510680_VAV3-AS1      1
# 9627      cg21510680_VAV3      1
# 9628    cg16614500_TMEM80      1
# 9629     cg16614500_DEAF1      1
#
# [9630 rows x 2 columns]

# %%
labels = df_labels["label"].tolist()

# %%
nebit_features
# Out:
#       ring   NetRank  NetShort  HeatDiff  InfoDiff
# 0        1  0.853574  0.825783  1.085045  0.129803
# 1        1  0.903701  1.196529  0.729632  0.016267
# 2        1  0.886602  0.876968  0.849829  0.017671
# 3        1  0.906007  1.087867  0.703557  0.016218
# 4        1  0.905790  1.078248  0.704444  0.016267
# ...    ...       ...       ...       ...       ...
# 9625     0  0.000000 -2.121710  0.000000  0.000000
# 9626     0  0.000000 -2.121710  0.000000  0.000000
# 9627     0  0.000000 -2.121710  0.000000  0.000000
# 9628     0  0.000000 -2.121710  0.000000  0.000000
# 9629     0  0.000000 -2.121710  0.000000  0.000000
#
# [9630 rows x 5 columns]

# %%
n_neighbors=50
min_dist=0.99
metric='correlation'

embeddings = umap.UMAP(n_neighbors=n_neighbors, 
                       min_dist=min_dist, 
                       metric='correlation').fit_transform(nebit_features)

# %%
# Create a DataFrame with UMAP components and labels
data = {"UMAP1": embeddings[:, 0], "UMAP2": embeddings[:, 1], "Label": labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=1.0)
#, palette="viridis", s=50, alpha=0.9
plt.title("UMAP Visualization of NeDBIT Embeddings")
plt.savefig("data/umap_NeDBIT_features_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()

# %%
df_labels_pred_P = features_and_labels_df[features_and_labels_df["label"] == 0]
df_labels_pred_P
# Out:
#                            name  degree  ring   NetRank       NetShort  \
# 0               cg15694422_MGLL     492     1  0.853574   5.179237e+02
# 1              cg22644321_TRIB1    3272     1  0.903701   5.830698e+02
# 2            cg26582754_PHACTR2    1440     1  0.886602   5.269176e+02
# 3              cg20758823_RUNX2    3220     1  0.906007   5.639762e+02
# 4             cg03688134_PLXNC1    3119     1  0.905790   5.622860e+02
# ...                         ...     ...   ...       ...            ...
# 8732          cg06713675_EXOSC9       1     0  0.000000  5.356309e-305
# 8733          cg05635388_EXOSC9       1     0  0.000000  5.356309e-305
# 8734  cg05332652_TCONS_00029157       1     0  0.000000  5.356309e-305
# 8735  cg02409829_TCONS_00029157       1     0  0.000000  5.356309e-305
# 8736           cg26371957_NINJ2       4     1  0.879873   2.863911e+02
#
#       HeatDiff  InfoDiff  label  label_binary
# 0     1.085045  0.129803      0             0
# 1     0.729632  0.016267      0             0
# 2     0.849829  0.017671      0             0
# 3     0.703557  0.016218      0             0
# 4     0.704444  0.016267      0             0
# ...        ...       ...    ...           ...
# 8732  0.000000  0.000000      0             0
# 8733  0.000000  0.000000      0             0
# 8734  0.000000  0.000000      0             0
# 8735  0.000000  0.000000      0             0
# 8736  0.912698  1.163957      0             0
#
# [181 rows x 9 columns]

# %%
df_labels_pred_LP = features_and_labels_df[features_and_labels_df["label"] == 1]
df_labels_pred_LP
# Out:
#                      name  degree  ring   NetRank       NetShort  HeatDiff  \
# 21       cg02387312_HECW2    3025     2  1.997577   4.291217e+02  0.007349
# 25       cg02061820_MBNL1    4365     2  1.998105   4.297580e+02  0.013406
# 27       cg10506318_ERCC8    3521     2  1.997695   4.309554e+02  0.013015
# 28     cg10506318_NDUFAF2    3521     2  1.997695   4.309554e+02  0.013015
# 33        cg23447233_MAEA    3092     2  1.997578   4.298247e+02  0.008389
# ...                   ...     ...   ...       ...            ...       ...
# 9625    cg18098750_TICAM2       1     0  0.000000  5.356309e-305  0.000000
# 9626  cg21510680_VAV3-AS1       1     0  0.000000  5.356309e-305  0.000000
# 9627      cg21510680_VAV3       1     0  0.000000  5.356309e-305  0.000000
# 9628    cg16614500_TMEM80       1     0  0.000000  5.356309e-305  0.000000
# 9629     cg16614500_DEAF1       1     0  0.000000  5.356309e-305  0.000000
#
#       InfoDiff  label  label_binary
# 21    0.016402      1             1
# 25    0.016071      1             1
# 27    0.016533      1             1
# 28    0.016533      1             1
# 33    0.016493      1             1
# ...        ...    ...           ...
# 9625  0.000000      1             1
# 9626  0.000000      1             1
# 9627  0.000000      1             1
# 9628  0.000000      1             1
# 9629  0.000000      1             1
#
# [2362 rows x 9 columns]

# %%
df_labels_pred_WN = features_and_labels_df[features_and_labels_df["label"] == 2]
df_labels_pred_WN
# Out:
#                     name  degree  ring   NetRank  NetShort  HeatDiff  \
# 22       cg09382646_PCNT    2461     2  1.997723  396.3777  0.009072
# 24    cg20822254_AFG3L1P    2862     2  1.997435  417.7713  0.008169
# 26     cg11123060_ANTXR2    2457     2  1.997873  393.2038  0.005095
# 29      cg05641051_TEX41    2596     2  1.997795  393.5852  0.008461
# 34      cg01519847_PTPRJ    2838     2  1.997787  407.6910  0.007679
# ...                  ...     ...   ...       ...       ...       ...
# 8412   cg06139908_VSTM2A    2345     2  1.999335  350.9971  0.001424
# 8414      cg13615030_AK1    2552     2  1.999234  385.3050  0.001484
# 8415    cg12028548_TCF15    2506     2  1.999414  351.7783  0.001354
# 8427   cg06447552_AMOTL1    2326     2  1.999535  348.1620  0.001066
# 8429  cg03141482_FAM155A    2370     2  1.999544  348.1851  0.000973
#
#       InfoDiff  label  label_binary
# 22    0.016919      2             1
# 24    0.016549      2             1
# 26    0.016465      2             1
# 29    0.016708      2             1
# 34    0.016583      2             1
# ...        ...    ...           ...
# 8412  0.014419      2             1
# 8414  0.014522      2             1
# 8415  0.014447      2             1
# 8427  0.014404      2             1
# 8429  0.014336      2             1
#
# [2362 rows x 9 columns]

# %%
df_labels_pred_LN = features_and_labels_df[features_and_labels_df["label"] == 3]
df_labels_pred_LN
# Out:
#                       name  degree  ring   NetRank  NetShort  HeatDiff  \
# 23    cg14543189_KIAA0319L    1694     2  1.998115  376.1874  0.003168
# 30       cg11108080_SLC1A2    2281     2  1.997934  395.0479  0.006817
# 32       cg16144306_HIVEP2    1960     2  1.998129  376.2985  0.003825
# 39      cg18976159_SLC35F2    2312     2  1.997741  390.4329  0.007989
# 63        cg15842544_FRAT2    2250     2  1.997708  410.5528  0.006429
# ...                    ...     ...   ...       ...       ...       ...
# 8571     cg02073954_ZNF193    1126     2  1.999398  326.0318  0.000585
# 8573     cg08327690_EPS8L2    1453     2  1.999533  329.6174  0.000617
# 8584     cg21379321_ZNF619    1260     2  1.999599  380.0221  0.000449
# 8613       cg00522018_LHX3    1042     2  1.999531  333.4750  0.000428
# 8618      cg20641465_PITX3    1007     2  1.999611  333.2212  0.000371
#
#       InfoDiff  label  label_binary
# 23    0.016647      3             1
# 30    0.016773      3             1
# 32    0.016630      3             1
# 39    0.016786      3             1
# 63    0.016754      3             1
# ...        ...    ...           ...
# 8571  0.013924      3             1
# 8573  0.014250      3             1
# 8584  0.014140      3             1
# 8613  0.013885      3             1
# 8618  0.014190      3             1
#
# [2362 rows x 9 columns]

# %%
df_labels_pred_RN = features_and_labels_df[features_and_labels_df["label"] == 4]
df_labels_pred_RN
# Out:
#                       name  degree  ring   NetRank   NetShort      HeatDiff  \
# 20       cg00716870_NDFIP1     106     2  1.991727  368.98100  1.397765e-03
# 31       cg07436694_METTL9     431     2  1.996192  361.67650  3.524957e-03
# 50       cg22328249_SEMA4D     112     2  1.996099  344.74460  8.138244e-04
# 65        cg20287234_GPR55      96     2  1.992992  355.83450  4.528758e-03
# 187     cg22970959_FAM107B     433     2  1.997243  363.49950  1.880607e-03
# ...                    ...     ...   ...       ...        ...           ...
# 9583  cg13507326_C14orf178       2     3  2.999172   71.90036  2.599156e-07
# 9584       cg06728252_ABT1       1     3  2.998312   91.38589  1.651721e-07
# 9593     cg09735274_TRIM31       1     4  3.999278   54.65890  9.284903e-09
# 9596      cg27436717_CDH13       1     4  3.999714   48.02148  2.705763e-08
# 9615     cg26705425_ZNF331       1     3  2.999193   91.86659  5.162806e-07
#
#           InfoDiff  label  label_binary
# 20    9.879548e-03      4             1
# 31    1.813891e-02      4             1
# 50    9.685422e-03      4             1
# 65    1.252863e-02      4             1
# 187   1.618646e-02      4             1
# ...            ...    ...           ...
# 9583  8.057906e-05      4             1
# 9584  8.067468e-05      4             1
# 9593  2.964103e-06      4             1
# 9596  1.939489e-07      4             1
# 9615  5.893033e-05      4             1
#
# [2363 rows x 9 columns]

# %%
df_merged_signals = pd.read_csv("data/merged_signals_bc.csv", sep="\t", engine="c")
df_merged_signals

# %%
feature_names = df_labels["name"].tolist()

# %%
dnam_signals = df_merged_signals[feature_names]
dnam_signals

# %%
dnam_signals_transpose = dnam_signals.transpose()
dnam_signals_transpose

# %%
dnam_signals_transpose.to_csv("data/dnam_signals_transpose.csv")

# %%
dnam_signals_transpose = dnam_signals_transpose.reset_index()
dnam_signals_transpose

# %%
dnam_features = dnam_signals_transpose.iloc[:, 1:]
dnam_features

# %%
n_neighbors=100 #10 #5
min_dist=0.99 #0.99 #0.3
metric='correlation'

dnam_embeddings = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(dnam_features)

# %%
data = {"UMAP1": dnam_embeddings[:, 0], "UMAP2": dnam_embeddings[:, 1], "Label": labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9) #, palette="viridis", s=50, alpha=0.9
plt.title("UMAP Visualization of Methylation patterns embeddings")
plt.savefig("data/umap_dnam_features_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()

# %%
nebit_features

# %%
#nebit_dnam_features = pd.concat([nebit_features, dnam_signals_transpose.iloc[:, 1:]], axis=1)
nebit_dnam_features = pd.concat([nebit_features, dnam_features], axis=1)
nebit_dnam_features

# %%
n_neighbors=20 #10 #5
min_dist=0.8 #0.99 #0.3
metric='correlation'

nebit_dnam_embeddings = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(nebit_dnam_features)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a data frame with UMAP components and labels
data = {"UMAP1": nebit_dnam_embeddings[:, 0], "UMAP2": nebit_dnam_embeddings[:, 1], "Label": labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9) #, palette="viridis", s=50, alpha=0.9
plt.title("UMAP Visualization of NeDBIT+Methylation embeddings")
plt.savefig("data/umap_NeDBIT_dnam_features_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()
