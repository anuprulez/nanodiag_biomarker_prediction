# %%
import pandas as pd

df_multi_group = pd.read_excel("data/ST3909_Proj_155_3_AG_Nazarenko_Ftest_multigroup_limma_results.xlsx") 
df_multi_group
# Out:
#      Log2 fold change EV/Ctrl  Log2 fold change T8/EV  \
# 0                    5.542202               -0.162447
# 1                    4.206573                0.230492
# 2                    5.578787                0.015519
# 3                    3.717479               -0.297074
# 4                    4.659921                0.235181
# ..                        ...                     ...
# 695                       NaN               -0.737234
# 696                       NaN                0.261662
# 697                       NaN               -0.412297
# 698                       NaN               -0.253792
# 699                       NaN               -0.760220
#
#      Log2 fold change T8/Ctrl  Average Expression      F test       p value  \
# 0                    5.379756           18.407863  110.771190  1.116041e-07
# 1                    4.437065           19.151769   91.568632  2.829821e-07
# 2                    5.594306           18.790141  110.891103  3.347983e-07
# 3                    3.420405           19.219070   87.639923  3.501737e-07
# 4                    4.895102           18.663681   87.230810  3.582142e-07
# ..                        ...                 ...         ...           ...
# 695                       NaN           15.567100         NaN           NaN
# 696                       NaN           15.572802         NaN           NaN
# 697                       NaN           15.644453         NaN           NaN
# 698                       NaN           15.781895         NaN           NaN
# 699                       NaN           15.110208         NaN           NaN
#
#      adjusted p value               Protein      Gene name  \
# 0             0.00001                P40926           MDH2
# 1             0.00001                P05556          ITGB1
# 2             0.00001         P11047;Q9Y6N6            NaN
# 3             0.00001  P18669;P15259;Q8N0Y7            NaN
# 4             0.00001                O14786           NRP1
# ..                ...                   ...            ...
# 695               NaN         Q8IXL6;Q96MK3  FAM20C;FAM20A
# 696               NaN                P23588          EIF4B
# 697               NaN                Q8NC51         SERBP1
# 698               NaN                Q9BZZ5           API5
# 699               NaN                P51665          PSMD7
#
#                                           Protein name
# 0                  Malate dehydrogenase, mitochondrial
# 1                                      Integrin beta-1
# 2                                                  NaN
# 3                                                  NaN
# 4                                         Neuropilin-1
# ..                                                 ...
# 695  Extracellular serine/threonine protein kinase ...
# 696        Eukaryotic translation initiation factor 4B
# 697  Plasminogen activator inhibitor 1 RNA-binding ...
# 698                              Apoptosis inhibitor 5
# 699     26S proteasome non-ATPase regulatory subunit 7
#
# [700 rows x 10 columns]

# %%
df_multi_group_t8 = df_multi_group.iloc[:, 1:]
df_multi_group_t8
# Out:
#      Log2 fold change T8/EV  Log2 fold change T8/Ctrl  Average Expression  \
# 0                 -0.162447                  5.379756           18.407863
# 1                  0.230492                  4.437065           19.151769
# 2                  0.015519                  5.594306           18.790141
# 3                 -0.297074                  3.420405           19.219070
# 4                  0.235181                  4.895102           18.663681
# ..                      ...                       ...                 ...
# 695               -0.737234                       NaN           15.567100
# 696                0.261662                       NaN           15.572802
# 697               -0.412297                       NaN           15.644453
# 698               -0.253792                       NaN           15.781895
# 699               -0.760220                       NaN           15.110208
#
#          F test       p value  adjusted p value               Protein  \
# 0    110.771190  1.116041e-07           0.00001                P40926
# 1     91.568632  2.829821e-07           0.00001                P05556
# 2    110.891103  3.347983e-07           0.00001         P11047;Q9Y6N6
# 3     87.639923  3.501737e-07           0.00001  P18669;P15259;Q8N0Y7
# 4     87.230810  3.582142e-07           0.00001                O14786
# ..          ...           ...               ...                   ...
# 695         NaN           NaN               NaN         Q8IXL6;Q96MK3
# 696         NaN           NaN               NaN                P23588
# 697         NaN           NaN               NaN                Q8NC51
# 698         NaN           NaN               NaN                Q9BZZ5
# 699         NaN           NaN               NaN                P51665
#
#          Gene name                                       Protein name
# 0             MDH2                Malate dehydrogenase, mitochondrial
# 1            ITGB1                                    Integrin beta-1
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4             NRP1                                       Neuropilin-1
# ..             ...                                                ...
# 695  FAM20C;FAM20A  Extracellular serine/threonine protein kinase ...
# 696          EIF4B        Eukaryotic translation initiation factor 4B
# 697         SERBP1  Plasminogen activator inhibitor 1 RNA-binding ...
# 698           API5                              Apoptosis inhibitor 5
# 699          PSMD7     26S proteasome non-ATPase regulatory subunit 7
#
# [700 rows x 9 columns]

# %%
df_p_val_corrected = df_multi_group_t8[df_multi_group_t8["p value"] < 0.05]
df_p_val_corrected, df_p_val_corrected.columns
# Out:
# (     Log2 fold change T8/EV  Log2 fold change T8/Ctrl  Average Expression  \
#  0                 -0.162447                  5.379756           18.407863
#  1                  0.230492                  4.437065           19.151769
#  2                  0.015519                  5.594306           18.790141
#  3                 -0.297074                  3.420405           19.219070
#  4                  0.235181                  4.895102           18.663681
#  ..                      ...                       ...                 ...
#  109               -0.434425                  1.202407           18.435171
#  110               -0.101496                  1.833872           19.750883
#  111               -0.391843                  1.248289           17.686449
#  112                0.448402                 -0.751345           18.816638
#  113                0.212937                  1.384582           16.989521
#
#           F test       p value  adjusted p value               Protein  \
#  0    110.771190  1.116041e-07          0.000010                P40926
#  1     91.568632  2.829821e-07          0.000010                P05556
#  2    110.891103  3.347983e-07          0.000010         P11047;Q9Y6N6
#  3     87.639923  3.501737e-07          0.000010  P18669;P15259;Q8N0Y7
#  4     87.230810  3.582142e-07          0.000010                O14786
#  ..          ...           ...               ...                   ...
#  109    4.988337  3.382622e-02          0.043528                P13591
#  110    4.783186  3.402534e-02          0.043528                P62826
#  111    4.564889  3.814550e-02          0.048363  P68371;P04350;Q3ZCM7
#  112    4.447442  4.060832e-02          0.051030         Q16853;O75106
#  113    4.533238  4.683879e-02          0.058343                P11021
#
#       Gene name                                       Protein name
#  0         MDH2                Malate dehydrogenase, mitochondrial
#  1        ITGB1                                    Integrin beta-1
#  2          NaN                                                NaN
#  3          NaN                                                NaN
#  4         NRP1                                       Neuropilin-1
#  ..         ...                                                ...
#  109      NCAM1                    Neural cell adhesion molecule 1
#  110        RAN                    GTP-binding nuclear protein Ran
#  111        NaN                                                NaN
#  112  AOC3;AOC2  Membrane primary amine oxidase;Retina-specific...
#  113      HSPA5                   78 kDa glucose-regulated protein
#
#  [114 rows x 9 columns],
#  Index(['Log2 fold change T8/EV', 'Log2 fold change T8/Ctrl',
#         'Average Expression', 'F test', 'p value', 'adjusted p value',
#         'Protein', 'Gene name', 'Protein name'],
#        dtype='object'))

# %%
log2FC_threshold = 1 
df_t8_ev_upregulated = df_p_val_corrected[df_p_val_corrected["Log2 fold change T8/EV"] >= log2FC_threshold]
df_t8_ev_upregulated.to_csv("T8-EV-Upregulated.csv", sep="\t", index=None)
df_t8_ev_upregulated
# Out:
#     Log2 fold change T8/EV  Log2 fold change T8/Ctrl  Average Expression  \
# 69                 1.16695                  3.162134           17.506837
#
#       F test   p value  adjusted p value Protein Gene name Protein name
# 69  23.80836  0.000222          0.000451  P24821       TNC     Tenascin

# %%
df_t8_ev_downregulated = df_p_val_corrected[df_p_val_corrected["Log2 fold change T8/EV"] < -log2FC_threshold]
df_t8_ev_downregulated.to_csv("T8-EV-Downregulated.csv", sep="\t", index=None)
df_t8_ev_downregulated
# Out:
# Empty DataFrame
# Columns: [Log2 fold change T8/EV, Log2 fold change T8/Ctrl, Average Expression, F test, p value, adjusted p value, Protein, Gene name, Protein name]
# Index: []

# %%
df_t8_ctrl_upregulated = df_p_val_corrected[df_p_val_corrected["Log2 fold change T8/Ctrl"] >= log2FC_threshold]
df_t8_ctrl_upregulated = df_t8_ctrl_upregulated.sort_values(by="Log2 fold change T8/Ctrl", ascending=False)
df_t8_ctrl_upregulated.to_csv("T8-Control-Upregulated.csv", sep="\t", index=None)
df_t8_ctrl_upregulated
# Out:
#      Log2 fold change T8/EV  Log2 fold change T8/Ctrl  Average Expression  \
# 13                 0.312758                  7.321975           19.126532
# 83                -0.075278                  6.661384           20.533344
# 6                 -0.364884                  6.498281           19.571889
# 15                 0.809358                  6.373974           19.950769
# 8                  0.540908                  6.110886           20.926120
# ..                      ...                       ...                 ...
# 113                0.212937                  1.384582           16.989521
# 104                0.248408                  1.371065           19.187900
# 111               -0.391843                  1.248289           17.686449
# 109               -0.434425                  1.202407           18.435171
# 108               -0.071273                  1.136495           17.559873
#
#         F test       p value  adjusted p value               Protein  \
# 13   65.400542  1.431111e-06          0.000015                O00468
# 83   14.343186  1.062449e-03          0.001796                P06733
# 6    62.772931  7.747797e-07          0.000015                P00338
# 15   50.645697  2.327404e-06          0.000021                P02751
# 8    58.282167  1.136054e-06          0.000015                P00749
# ..         ...           ...               ...                   ...
# 113   4.533238  4.683879e-02          0.058343                P11021
# 104   5.793209  2.067726e-02          0.027964                P35052
# 111   4.564889  3.814550e-02          0.048363  P68371;P04350;Q3ZCM7
# 109   4.988337  3.382622e-02          0.043528                P13591
# 108   5.254457  2.980794e-02          0.038832                P55290
#
#     Gene name                                       Protein name
# 13       AGRN  Agrin;Agrin N-terminal 110 kDa subunit;Agrin C...
# 83       ENO1                                      Alpha-enolase
# 6        LDHA                    L-lactate dehydrogenase A chain
# 15        FN1        Fibronectin;Anastellin;Ugl-Y1;Ugl-Y2;Ugl-Y3
# 8        PLAU  Urokinase-type plasminogen activator;Urokinase...
# ..        ...                                                ...
# 113     HSPA5                   78 kDa glucose-regulated protein
# 104      GPC1                     Glypican-1;Secreted glypican-1
# 111       NaN                                                NaN
# 109     NCAM1                    Neural cell adhesion molecule 1
# 108     CDH13                                        Cadherin-13
#
# [109 rows x 9 columns]

# %%
df_t8_ctrl_downregulated = df_p_val_corrected[df_p_val_corrected["Log2 fold change T8/Ctrl"] < -log2FC_threshold]
df_t8_ctrl_downregulated = df_t8_ctrl_downregulated.sort_values(by='Log2 fold change T8/Ctrl', ascending=True)
df_t8_ctrl_downregulated
# Out:
#     Log2 fold change T8/EV  Log2 fold change T8/Ctrl  Average Expression  \
# 68               -0.338504                 -2.809848           16.801586
# 65                0.643936                 -2.383547           22.259092
# 93                0.035237                 -1.951299           18.238177
# 96               -0.040337                 -1.558692           19.227832
#
#        F test   p value  adjusted p value Protein Gene name  \
# 68  24.252490  0.000207          0.000426  Q8NI36     WDR36
# 65  22.292382  0.000183          0.000394  P02656     APOC3
# 93  11.246465  0.002585          0.003906  P04114      APOB
# 96   9.246708  0.005046          0.007387  P02753      RBP4
#
#                                          Protein name
# 68                    WD repeat-containing protein 36
# 65                               Apolipoprotein C-III
# 93           Apolipoprotein B-100;Apolipoprotein B-48
# 96  Retinol-binding protein 4;Plasma retinol-bindi...
