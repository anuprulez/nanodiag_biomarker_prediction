# %%
import numpy as np 
import pandas as pd

# %%
base_path = "data/"

# %%
nedbit_path = "df_nebit_dnam_features_bc.csv"
df_nebit_features = pd.read_csv(base_path + nedbit_path, sep=",")
df_nebit_features
# Out:
#                       name  class  degree  ring   NetRank   NetShort  \
# 0          cg15694422_MGLL      1     460     1  0.844475  415.86290
# 1         cg02116768_FOXK2      1     761     1  0.883759  426.04770
# 2        cg13675051_RNF19A      1     690     1  0.884858  408.35680
# 3         cg22644321_TRIB1      1    1290     1  0.898153  419.29990
# 4        cg18881723_SLAMF1      1    1054     1  0.897157  415.47340
# ...                    ...    ...     ...   ...       ...        ...
# 10192  cg23018707_C12orf35      0       6     3  2.998150   85.12343
# 10193   cg23930101_DENND6A      0       6     3  2.998234   91.64322
# 10194      cg12047283_SGK1      0       5     3  2.996472   84.35021
# 10195    cg04225510_CDC123      0      10     3  2.998520   92.73646
# 10196     cg04225510_NUDT5      0      10     3  2.998520   92.73646
#
#        HeatDiff  InfoDiff         0         1  ...        71        72  \
# 0      1.078528  0.198717  0.420649  0.315654  ...  0.304428  0.370463
# 1      0.803134  0.079001  0.460033  0.534132  ...  0.535238  0.619850
# 2      0.792330  0.094667  0.626586  0.650939  ...  0.733005  0.619955
# 3      0.727866  0.044253  0.312701  0.229696  ...  0.355249  0.366740
# 4      0.723161  0.044574  0.216552  0.208266  ...  0.291454  0.294704
# ...         ...       ...       ...       ...  ...       ...       ...
# 10192  0.000006  0.000146  0.956403  0.949201  ...  0.931376  0.942083
# 10193  0.000005  0.000263  0.073070  0.065043  ...  0.044973  0.036082
# 10194  0.000009  0.000114  0.040553  0.044754  ...  0.012554  0.001959
# 10195  0.000007  0.000335  0.024945  0.045394  ...  0.026448  0.055935
# 10196  0.000007  0.000335  0.024945  0.045394  ...  0.026448  0.055935
#
#              73        74        75        76        77        78        79  \
# 0      0.571908  0.439803  0.560614  0.483471  0.521094  0.464730  0.438450
# 1      0.615523  0.568770  0.663921  0.508202  0.490106  0.607031  0.537934
# 2      0.627940  0.730569  0.685908  0.667258  0.667705  0.627836  0.626844
# 3      0.348679  0.294176  0.440183  0.340785  0.258195  0.289059  0.283135
# 4      0.315083  0.198489  0.371205  0.226932  0.206108  0.235276  0.248134
# ...         ...       ...       ...       ...       ...       ...       ...
# 10192  0.967812  0.961334  0.960627  0.956324  0.916125  0.948923  0.957488
# 10193  0.031618  0.027711  0.028170  0.028191  0.032141  0.020509  0.022426
# 10194  0.021630  0.026853  0.007394  0.049421  0.056186  0.043922  0.033947
# 10195  0.051273  0.131382  0.063877  0.063944  0.013980  0.045494  0.082493
# 10196  0.051273  0.131382  0.063877  0.063944  0.013980  0.045494  0.082493
#
#        labels
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 10192       5
# 10193       5
# 10194       5
# 10195       5
# 10196       5
#
# [10197 rows x 89 columns]

# %%
df_test_probe_genes = pd.read_csv(base_path + "test_probe_genes.csv", sep=",")
df_test_probe_genes.head()
# Out:
#    test_gene_ids    test_gene_names
# 0           5133    cg12533642_RMI2
# 1           3742   cg06055669_CSMD1
# 2           9041  cg20829404_COL9A3
# 3           5135  cg17749961_LCLAT1
# 4           6521   cg01937505_CLOCK

# %%
probe_gene_list = df_test_probe_genes.iloc[:, 1].tolist()
len(probe_gene_list), probe_gene_list[:5]
# Out:
# (2797,
#  ['cg12533642_RMI2',
#   'cg06055669_CSMD1',
#   'cg20829404_COL9A3',
#   'cg17749961_LCLAT1',
#   'cg01937505_CLOCK'])

# %%
df_nebit_features_test = df_nebit_features[df_nebit_features["name"].isin(probe_gene_list)]
df_nebit_features_test.reset_index(drop=True, inplace=True)
df_nebit_features_test
# Out:
#                       name  class  degree  ring   NetRank   NetShort  \
# 0          cg15694422_MGLL      1     460     1  0.844475  415.86290
# 1         cg22644321_TRIB1      1    1290     1  0.898153  419.29990
# 2         cg20758823_RUNX2      1     913     1  0.897646  411.96870
# 3        cg22832271_ARID5B      1     932     1  0.886212  426.53890
# 4         cg17776881_MEF2C      1     577     1  0.876587  407.23370
# ...                    ...    ...     ...   ...       ...        ...
# 2792       cg05873605_SETX      0       8     3  2.998988   89.70450
# 2793     cg01819759_RNF219      0      10     3  2.999188   83.02828
# 2794     cg03086067_SH2D4B      0       4     3  2.999208   90.45815
# 2795         cg12768975_C3      0       7     3  2.998381   87.16984
# 2796  cg01343663_LINC01502      0      13     3  2.999682   91.52240
#
#       HeatDiff  InfoDiff         0         1  ...        71        72  \
# 0     1.078528  0.198717  0.420649  0.315654  ...  0.304428  0.370463
# 1     0.727866  0.044253  0.312701  0.229696  ...  0.355249  0.366740
# 2     0.708893  0.064919  0.430651  0.508906  ...  0.531396  0.537635
# 3     0.795989  0.057060  0.256703  0.296823  ...  0.475500  0.329951
# 4     0.846118  0.122924  0.314964  0.250373  ...  0.351960  0.417624
# ...        ...       ...       ...       ...  ...       ...       ...
# 2792  0.000003  0.000056  0.978743  0.975147  ...  0.967077  0.952911
# 2793  0.000024  0.000036  0.246064  0.181775  ...  0.306329  0.248957
# 2794  0.000001  0.000087  0.463305  0.463901  ...  0.455787  0.226938
# 2795  0.000006  0.000018  0.567607  0.181335  ...  0.207008  0.551647
# 2796  0.000013  0.000119  0.979235  0.985307  ...  0.967682  0.928106
#
#             73        74        75        76        77        78        79  \
# 0     0.571908  0.439803  0.560614  0.483471  0.521094  0.464730  0.438450
# 1     0.348679  0.294176  0.440183  0.340785  0.258195  0.289059  0.283135
# 2     0.501953  0.448602  0.597685  0.404161  0.400028  0.422716  0.466858
# 3     0.352985  0.345143  0.440366  0.317415  0.247614  0.334988  0.312502
# 4     0.431051  0.438103  0.450741  0.332239  0.275716  0.425515  0.470709
# ...        ...       ...       ...       ...       ...       ...       ...
# 2792  0.952860  0.960463  0.949606  0.954800  0.928092  0.939847  0.948152
# 2793  0.177412  0.475398  0.510954  0.124151  0.607037  0.478428  0.115471
# 2794  0.287705  0.486991  0.366356  0.284489  0.517643  0.539067  0.344195
# 2795  0.504781  0.547805  0.475360  0.552860  0.078884  0.547311  0.186670
# 2796  0.979455  0.990519  0.984228  0.986848  0.968630  0.920839  0.943231
#
#       labels
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 2792       5
# 2793       5
# 2794       5
# 2795       5
# 2796       5
#
# [2797 rows x 89 columns]

# %%
nebit_features = df_nebit_features_test.iloc[:, 2:-1]
nebit_features
# Out:
#       degree  ring   NetRank   NetShort  HeatDiff  InfoDiff         0  \
# 0        460     1  0.844475  415.86290  1.078528  0.198717  0.420649
# 1       1290     1  0.898153  419.29990  0.727866  0.044253  0.312701
# 2        913     1  0.897646  411.96870  0.708893  0.064919  0.430651
# 3        932     1  0.886212  426.53890  0.795989  0.057060  0.256703
# 4        577     1  0.876587  407.23370  0.846118  0.122924  0.314964
# ...      ...   ...       ...        ...       ...       ...       ...
# 2792       8     3  2.998988   89.70450  0.000003  0.000056  0.978743
# 2793      10     3  2.999188   83.02828  0.000024  0.000036  0.246064
# 2794       4     3  2.999208   90.45815  0.000001  0.000087  0.463305
# 2795       7     3  2.998381   87.16984  0.000006  0.000018  0.567607
# 2796      13     3  2.999682   91.52240  0.000013  0.000119  0.979235
#
#              1         2         3  ...        70        71        72  \
# 0     0.315654  0.371301  0.265431  ...  0.488162  0.304428  0.370463
# 1     0.229696  0.243923  0.194979  ...  0.308620  0.355249  0.366740
# 2     0.508906  0.430397  0.333302  ...  0.510157  0.531396  0.537635
# 3     0.296823  0.308911  0.218024  ...  0.336222  0.475500  0.329951
# 4     0.250373  0.259187  0.238015  ...  0.375233  0.351960  0.417624
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.968250  0.967077  0.952911
# 2793  0.181775  0.281177  0.396663  ...  0.270235  0.306329  0.248957
# 2794  0.463901  0.399910  0.368827  ...  0.393080  0.455787  0.226938
# 2795  0.181335  0.163493  0.522188  ...  0.264503  0.207008  0.551647
# 2796  0.985307  0.982901  0.983414  ...  0.981265  0.967682  0.928106
#
#             73        74        75        76        77        78        79
# 0     0.571908  0.439803  0.560614  0.483471  0.521094  0.464730  0.438450
# 1     0.348679  0.294176  0.440183  0.340785  0.258195  0.289059  0.283135
# 2     0.501953  0.448602  0.597685  0.404161  0.400028  0.422716  0.466858
# 3     0.352985  0.345143  0.440366  0.317415  0.247614  0.334988  0.312502
# 4     0.431051  0.438103  0.450741  0.332239  0.275716  0.425515  0.470709
# ...        ...       ...       ...       ...       ...       ...       ...
# 2792  0.952860  0.960463  0.949606  0.954800  0.928092  0.939847  0.948152
# 2793  0.177412  0.475398  0.510954  0.124151  0.607037  0.478428  0.115471
# 2794  0.287705  0.486991  0.366356  0.284489  0.517643  0.539067  0.344195
# 2795  0.504781  0.547805  0.475360  0.552860  0.078884  0.547311  0.186670
# 2796  0.979455  0.990519  0.984228  0.986848  0.968630  0.920839  0.943231
#
# [2797 rows x 86 columns]

# %%
from sklearn.preprocessing import normalize, RobustScaler

def scale_features(list_feature_names, df_features):

    for feature_name in list_feature_names:
        print("Scaling: {}".format(feature_name))
        feature_val = np.array(df_features[feature_name].tolist())
        feature_val = feature_val.reshape(-1, 1)
        print(len(feature_val), feature_val.shape)
        transformer = RobustScaler().fit(feature_val)
        norm_feature_val = transformer.transform(feature_val)
        df_features[feature_name] = norm_feature_val
        
    return df_features

# %%
nebit_features_norm = scale_features(["degree", "ring", "NetShort"], nebit_features)
nebit_features_norm
# Out:
# Scaling: degree
# 2797 (2797, 1)
# Scaling: ring
# 2797 (2797, 1)
# Scaling: NetShort
# 2797 (2797, 1)
#         degree  ring   NetRank  NetShort  HeatDiff  InfoDiff         0  \
# 0     0.966667  -1.0  0.844475  1.186854  1.078528  0.198717  0.420649
# 1     2.942857  -1.0  0.898153  1.204743  0.727866  0.044253  0.312701
# 2     2.045238  -1.0  0.897646  1.166586  0.708893  0.064919  0.430651
# 3     2.090476  -1.0  0.886212  1.242420  0.795989  0.057060  0.256703
# 4     1.245238  -1.0  0.876587  1.141941  0.846118  0.122924  0.314964
# ...        ...   ...       ...       ...       ...       ...       ...
# 2792 -0.109524   1.0  2.998988 -0.510730  0.000003  0.000056  0.978743
# 2793 -0.104762   1.0  2.999188 -0.545478  0.000024  0.000036  0.246064
# 2794 -0.119048   1.0  2.999208 -0.506807  0.000001  0.000087  0.463305
# 2795 -0.111905   1.0  2.998381 -0.523922  0.000006  0.000018  0.567607
# 2796 -0.097619   1.0  2.999682 -0.501268  0.000013  0.000119  0.979235
#
#              1         2         3  ...        72        73        74  \
# 0     0.315654  0.371301  0.265431  ...  0.370463  0.571908  0.439803
# 1     0.229696  0.243923  0.194979  ...  0.366740  0.348679  0.294176
# 2     0.508906  0.430397  0.333302  ...  0.537635  0.501953  0.448602
# 3     0.296823  0.308911  0.218024  ...  0.329951  0.352985  0.345143
# 4     0.250373  0.259187  0.238015  ...  0.417624  0.431051  0.438103
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.952911  0.952860  0.960463
# 2793  0.181775  0.281177  0.396663  ...  0.248957  0.177412  0.475398
# 2794  0.463901  0.399910  0.368827  ...  0.226938  0.287705  0.486991
# 2795  0.181335  0.163493  0.522188  ...  0.551647  0.504781  0.547805
# 2796  0.985307  0.982901  0.983414  ...  0.928106  0.979455  0.990519
#
#             75        76        77        78        79  labels  \
# 0     0.560614  0.483471  0.521094  0.464730  0.438450       1
# 1     0.440183  0.340785  0.258195  0.289059  0.283135       1
# 2     0.597685  0.404161  0.400028  0.422716  0.466858       1
# 3     0.440366  0.317415  0.247614  0.334988  0.312502       1
# 4     0.450741  0.332239  0.275716  0.425515  0.470709       1
# ...        ...       ...       ...       ...       ...     ...
# 2792  0.949606  0.954800  0.928092  0.939847  0.948152       5
# 2793  0.510954  0.124151  0.607037  0.478428  0.115471       5
# 2794  0.366356  0.284489  0.517643  0.539067  0.344195       5
# 2795  0.475360  0.552860  0.078884  0.547311  0.186670       5
# 2796  0.984228  0.986848  0.968630  0.920839  0.943231       5
#
#              feature_names
# 0          cg15694422_MGLL
# 1         cg22644321_TRIB1
# 2         cg20758823_RUNX2
# 3        cg22832271_ARID5B
# 4         cg17776881_MEF2C
# ...                    ...
# 2792       cg05873605_SETX
# 2793     cg01819759_RNF219
# 2794     cg03086067_SH2D4B
# 2795         cg12768975_C3
# 2796  cg01343663_LINC01502
#
# [2797 rows x 88 columns]

# %%
feature_name = df_nebit_features_test.iloc[:, 0]
labels = df_nebit_features_test.iloc[:, -1]

df_labels = pd.DataFrame(zip(feature_name.tolist(), labels.tolist()), columns=["feature_name", "labels"])
df_labels
# Out:
#               feature_name  labels
# 0          cg15694422_MGLL       1
# 1         cg22644321_TRIB1       1
# 2         cg20758823_RUNX2       1
# 3        cg22832271_ARID5B       1
# 4         cg17776881_MEF2C       1
# ...                    ...     ...
# 2792       cg05873605_SETX       5
# 2793     cg01819759_RNF219       5
# 2794     cg03086067_SH2D4B       5
# 2795         cg12768975_C3       5
# 2796  cg01343663_LINC01502       5
#
# [2797 rows x 2 columns]

# %%
nebit_features_norm_umap = nebit_features_norm.iloc[:, :-2]
nebit_features_norm_umap
# Out:
#         degree  ring   NetRank  NetShort  HeatDiff  InfoDiff         0  \
# 0     0.966667  -1.0  0.844475  1.186854  1.078528  0.198717  0.420649
# 1     2.942857  -1.0  0.898153  1.204743  0.727866  0.044253  0.312701
# 2     2.045238  -1.0  0.897646  1.166586  0.708893  0.064919  0.430651
# 3     2.090476  -1.0  0.886212  1.242420  0.795989  0.057060  0.256703
# 4     1.245238  -1.0  0.876587  1.141941  0.846118  0.122924  0.314964
# ...        ...   ...       ...       ...       ...       ...       ...
# 2792 -0.109524   1.0  2.998988 -0.510730  0.000003  0.000056  0.978743
# 2793 -0.104762   1.0  2.999188 -0.545478  0.000024  0.000036  0.246064
# 2794 -0.119048   1.0  2.999208 -0.506807  0.000001  0.000087  0.463305
# 2795 -0.111905   1.0  2.998381 -0.523922  0.000006  0.000018  0.567607
# 2796 -0.097619   1.0  2.999682 -0.501268  0.000013  0.000119  0.979235
#
#              1         2         3  ...        70        71        72  \
# 0     0.315654  0.371301  0.265431  ...  0.488162  0.304428  0.370463
# 1     0.229696  0.243923  0.194979  ...  0.308620  0.355249  0.366740
# 2     0.508906  0.430397  0.333302  ...  0.510157  0.531396  0.537635
# 3     0.296823  0.308911  0.218024  ...  0.336222  0.475500  0.329951
# 4     0.250373  0.259187  0.238015  ...  0.375233  0.351960  0.417624
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.968250  0.967077  0.952911
# 2793  0.181775  0.281177  0.396663  ...  0.270235  0.306329  0.248957
# 2794  0.463901  0.399910  0.368827  ...  0.393080  0.455787  0.226938
# 2795  0.181335  0.163493  0.522188  ...  0.264503  0.207008  0.551647
# 2796  0.985307  0.982901  0.983414  ...  0.981265  0.967682  0.928106
#
#             73        74        75        76        77        78        79
# 0     0.571908  0.439803  0.560614  0.483471  0.521094  0.464730  0.438450
# 1     0.348679  0.294176  0.440183  0.340785  0.258195  0.289059  0.283135
# 2     0.501953  0.448602  0.597685  0.404161  0.400028  0.422716  0.466858
# 3     0.352985  0.345143  0.440366  0.317415  0.247614  0.334988  0.312502
# 4     0.431051  0.438103  0.450741  0.332239  0.275716  0.425515  0.470709
# ...        ...       ...       ...       ...       ...       ...       ...
# 2792  0.952860  0.960463  0.949606  0.954800  0.928092  0.939847  0.948152
# 2793  0.177412  0.475398  0.510954  0.124151  0.607037  0.478428  0.115471
# 2794  0.287705  0.486991  0.366356  0.284489  0.517643  0.539067  0.344195
# 2795  0.504781  0.547805  0.475360  0.552860  0.078884  0.547311  0.186670
# 2796  0.979455  0.990519  0.984228  0.986848  0.968630  0.920839  0.943231
#
# [2797 rows x 86 columns]

# %%
import umap
import seaborn as sns
import matplotlib.pyplot as plt

n_neighbors=20 #10 #5
min_dist=0.8 #0.99 #0.99 #0.3
metric='correlation'

embeddings = umap.UMAP(n_neighbors=n_neighbors, min_dist=min_dist, metric='correlation').fit_transform(nebit_features_norm_umap)

# %%
# Create a DataFrame with UMAP components and labels
data = {"UMAP1": embeddings[:, 0], "UMAP2": embeddings[:, 1], "Label": labels}
df_test = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df_test, palette="viridis", s=50, alpha=1.0)
#, palette="viridis", s=50, alpha=0.9
plt.title("UMAP Visualization of NeDBIT + DNA Methylation features for test data")
plt.savefig(base_path + "umap_NeDBIT_DNAM_features_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()

# %%
feature_names = df_labels["feature_name"].tolist()

# %%
#nebit_features = nebit_features.reset_index()
nebit_features
# Out:
#         degree  ring   NetRank  NetShort  HeatDiff  InfoDiff         0  \
# 0     0.966667  -1.0  0.844475  1.186854  1.078528  0.198717  0.420649
# 1     2.942857  -1.0  0.898153  1.204743  0.727866  0.044253  0.312701
# 2     2.045238  -1.0  0.897646  1.166586  0.708893  0.064919  0.430651
# 3     2.090476  -1.0  0.886212  1.242420  0.795989  0.057060  0.256703
# 4     1.245238  -1.0  0.876587  1.141941  0.846118  0.122924  0.314964
# ...        ...   ...       ...       ...       ...       ...       ...
# 2792 -0.109524   1.0  2.998988 -0.510730  0.000003  0.000056  0.978743
# 2793 -0.104762   1.0  2.999188 -0.545478  0.000024  0.000036  0.246064
# 2794 -0.119048   1.0  2.999208 -0.506807  0.000001  0.000087  0.463305
# 2795 -0.111905   1.0  2.998381 -0.523922  0.000006  0.000018  0.567607
# 2796 -0.097619   1.0  2.999682 -0.501268  0.000013  0.000119  0.979235
#
#              1         2         3  ...        70        71        72  \
# 0     0.315654  0.371301  0.265431  ...  0.488162  0.304428  0.370463
# 1     0.229696  0.243923  0.194979  ...  0.308620  0.355249  0.366740
# 2     0.508906  0.430397  0.333302  ...  0.510157  0.531396  0.537635
# 3     0.296823  0.308911  0.218024  ...  0.336222  0.475500  0.329951
# 4     0.250373  0.259187  0.238015  ...  0.375233  0.351960  0.417624
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.968250  0.967077  0.952911
# 2793  0.181775  0.281177  0.396663  ...  0.270235  0.306329  0.248957
# 2794  0.463901  0.399910  0.368827  ...  0.393080  0.455787  0.226938
# 2795  0.181335  0.163493  0.522188  ...  0.264503  0.207008  0.551647
# 2796  0.985307  0.982901  0.983414  ...  0.981265  0.967682  0.928106
#
#             73        74        75        76        77        78        79
# 0     0.571908  0.439803  0.560614  0.483471  0.521094  0.464730  0.438450
# 1     0.348679  0.294176  0.440183  0.340785  0.258195  0.289059  0.283135
# 2     0.501953  0.448602  0.597685  0.404161  0.400028  0.422716  0.466858
# 3     0.352985  0.345143  0.440366  0.317415  0.247614  0.334988  0.312502
# 4     0.431051  0.438103  0.450741  0.332239  0.275716  0.425515  0.470709
# ...        ...       ...       ...       ...       ...       ...       ...
# 2792  0.952860  0.960463  0.949606  0.954800  0.928092  0.939847  0.948152
# 2793  0.177412  0.475398  0.510954  0.124151  0.607037  0.478428  0.115471
# 2794  0.287705  0.486991  0.366356  0.284489  0.517643  0.539067  0.344195
# 2795  0.504781  0.547805  0.475360  0.552860  0.078884  0.547311  0.186670
# 2796  0.979455  0.990519  0.984228  0.986848  0.968630  0.920839  0.943231
#
# [2797 rows x 86 columns]

# %%
#dnam_features

# %%
nebit_dnam_features = nebit_features
nebit_dnam_features
# Out:
#         degree  ring   NetRank  NetShort  HeatDiff  InfoDiff         0  \
# 0     0.966667  -1.0  0.844475  1.186854  1.078528  0.198717  0.420649
# 1     2.942857  -1.0  0.898153  1.204743  0.727866  0.044253  0.312701
# 2     2.045238  -1.0  0.897646  1.166586  0.708893  0.064919  0.430651
# 3     2.090476  -1.0  0.886212  1.242420  0.795989  0.057060  0.256703
# 4     1.245238  -1.0  0.876587  1.141941  0.846118  0.122924  0.314964
# ...        ...   ...       ...       ...       ...       ...       ...
# 2792 -0.109524   1.0  2.998988 -0.510730  0.000003  0.000056  0.978743
# 2793 -0.104762   1.0  2.999188 -0.545478  0.000024  0.000036  0.246064
# 2794 -0.119048   1.0  2.999208 -0.506807  0.000001  0.000087  0.463305
# 2795 -0.111905   1.0  2.998381 -0.523922  0.000006  0.000018  0.567607
# 2796 -0.097619   1.0  2.999682 -0.501268  0.000013  0.000119  0.979235
#
#              1         2         3  ...        70        71        72  \
# 0     0.315654  0.371301  0.265431  ...  0.488162  0.304428  0.370463
# 1     0.229696  0.243923  0.194979  ...  0.308620  0.355249  0.366740
# 2     0.508906  0.430397  0.333302  ...  0.510157  0.531396  0.537635
# 3     0.296823  0.308911  0.218024  ...  0.336222  0.475500  0.329951
# 4     0.250373  0.259187  0.238015  ...  0.375233  0.351960  0.417624
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.968250  0.967077  0.952911
# 2793  0.181775  0.281177  0.396663  ...  0.270235  0.306329  0.248957
# 2794  0.463901  0.399910  0.368827  ...  0.393080  0.455787  0.226938
# 2795  0.181335  0.163493  0.522188  ...  0.264503  0.207008  0.551647
# 2796  0.985307  0.982901  0.983414  ...  0.981265  0.967682  0.928106
#
#             73        74        75        76        77        78        79
# 0     0.571908  0.439803  0.560614  0.483471  0.521094  0.464730  0.438450
# 1     0.348679  0.294176  0.440183  0.340785  0.258195  0.289059  0.283135
# 2     0.501953  0.448602  0.597685  0.404161  0.400028  0.422716  0.466858
# 3     0.352985  0.345143  0.440366  0.317415  0.247614  0.334988  0.312502
# 4     0.431051  0.438103  0.450741  0.332239  0.275716  0.425515  0.470709
# ...        ...       ...       ...       ...       ...       ...       ...
# 2792  0.952860  0.960463  0.949606  0.954800  0.928092  0.939847  0.948152
# 2793  0.177412  0.475398  0.510954  0.124151  0.607037  0.478428  0.115471
# 2794  0.287705  0.486991  0.366356  0.284489  0.517643  0.539067  0.344195
# 2795  0.504781  0.547805  0.475360  0.552860  0.078884  0.547311  0.186670
# 2796  0.979455  0.990519  0.984228  0.986848  0.968630  0.920839  0.943231
#
# [2797 rows x 86 columns]

# %%
n_neighbors=20 #20 #10 #5
min_dist=0.8 #0.8 #0.99 #0.3
metric='correlation'

nebit_dnam_embeddings = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(nebit_dnam_features)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a data frame with UMAP components and labels
data = {"UMAP1": nebit_dnam_embeddings[:, 0], "UMAP2": nebit_dnam_embeddings[:, 1], "Label": labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9) #, palette="viridis", s=50, alpha=0.9
plt.title("UMAP Visualization of NeDBIT+Methylation embeddings")
plt.savefig(base_path + "umap_NeDBIT_dnam_features_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()

# %%
df_nebit_dnam_features = nebit_dnam_features

# %%
df_nebit_dnam_features["labels"] = labels
df_nebit_dnam_features["feature_names"] = df_labels["feature_name"].tolist()

# %%
file_path = base_path + "df_nebit_dnam_features_test.csv"
df_nebit_dnam_features.to_csv(file_path, sep="\t", header=None, index=None)
df_nebit_dnam_features
# Out:
#         degree  ring   NetRank  NetShort  HeatDiff  InfoDiff         0  \
# 0     0.966667  -1.0  0.844475  1.186854  1.078528  0.198717  0.420649
# 1     2.942857  -1.0  0.898153  1.204743  0.727866  0.044253  0.312701
# 2     2.045238  -1.0  0.897646  1.166586  0.708893  0.064919  0.430651
# 3     2.090476  -1.0  0.886212  1.242420  0.795989  0.057060  0.256703
# 4     1.245238  -1.0  0.876587  1.141941  0.846118  0.122924  0.314964
# ...        ...   ...       ...       ...       ...       ...       ...
# 2792 -0.109524   1.0  2.998988 -0.510730  0.000003  0.000056  0.978743
# 2793 -0.104762   1.0  2.999188 -0.545478  0.000024  0.000036  0.246064
# 2794 -0.119048   1.0  2.999208 -0.506807  0.000001  0.000087  0.463305
# 2795 -0.111905   1.0  2.998381 -0.523922  0.000006  0.000018  0.567607
# 2796 -0.097619   1.0  2.999682 -0.501268  0.000013  0.000119  0.979235
#
#              1         2         3  ...        72        73        74  \
# 0     0.315654  0.371301  0.265431  ...  0.370463  0.571908  0.439803
# 1     0.229696  0.243923  0.194979  ...  0.366740  0.348679  0.294176
# 2     0.508906  0.430397  0.333302  ...  0.537635  0.501953  0.448602
# 3     0.296823  0.308911  0.218024  ...  0.329951  0.352985  0.345143
# 4     0.250373  0.259187  0.238015  ...  0.417624  0.431051  0.438103
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.952911  0.952860  0.960463
# 2793  0.181775  0.281177  0.396663  ...  0.248957  0.177412  0.475398
# 2794  0.463901  0.399910  0.368827  ...  0.226938  0.287705  0.486991
# 2795  0.181335  0.163493  0.522188  ...  0.551647  0.504781  0.547805
# 2796  0.985307  0.982901  0.983414  ...  0.928106  0.979455  0.990519
#
#             75        76        77        78        79  labels  \
# 0     0.560614  0.483471  0.521094  0.464730  0.438450       1
# 1     0.440183  0.340785  0.258195  0.289059  0.283135       1
# 2     0.597685  0.404161  0.400028  0.422716  0.466858       1
# 3     0.440366  0.317415  0.247614  0.334988  0.312502       1
# 4     0.450741  0.332239  0.275716  0.425515  0.470709       1
# ...        ...       ...       ...       ...       ...     ...
# 2792  0.949606  0.954800  0.928092  0.939847  0.948152       5
# 2793  0.510954  0.124151  0.607037  0.478428  0.115471       5
# 2794  0.366356  0.284489  0.517643  0.539067  0.344195       5
# 2795  0.475360  0.552860  0.078884  0.547311  0.186670       5
# 2796  0.984228  0.986848  0.968630  0.920839  0.943231       5
#
#              feature_names
# 0          cg15694422_MGLL
# 1         cg22644321_TRIB1
# 2         cg20758823_RUNX2
# 3        cg22832271_ARID5B
# 4         cg17776881_MEF2C
# ...                    ...
# 2792       cg05873605_SETX
# 2793     cg01819759_RNF219
# 2794     cg03086067_SH2D4B
# 2795         cg12768975_C3
# 2796  cg01343663_LINC01502
#
# [2797 rows x 88 columns]

# %%
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import umap

base_path = "data/"
base_plot_path = "data/"
embed_conv = torch.load(base_path + "embed_conv.pt")
embed_batch_norm = torch.load(base_path + "embed_batch_norm.pt")
true_labels = torch.load(base_path + "true_labels.pt")
pred_labels = torch.load(base_path + "pred_labels.pt")
true_labels = [int(item) + 1 for item in true_labels]
pred_labels = [int(item) + 1 for item in pred_labels]

# %%
n_neighbors=20 #10 #5
min_dist=0.8 #0.99 #0.3
metric='correlation'

umap_bn_embed = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(embed_batch_norm)

# Create a DataFrame with UMAP components and labels
data = {"UMAP1": umap_bn_embed[:, 0], "UMAP2": umap_bn_embed[:, 1], "Label": true_labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9)
plt.title("UMAP Visualization (GNN Batch Norm layer), True labels")
plt.savefig(base_plot_path + "umap_batch_norm_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()

# %%
n_neighbors=20 #10 #5
min_dist=0.8 #0.99 #0.3
metric='correlation'

umap_bn_embed = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(embed_batch_norm)

# Create a DataFrame with UMAP components and labels
data = {"UMAP1": umap_bn_embed[:, 0], "UMAP2": umap_bn_embed[:, 1], "Label": pred_labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9)
plt.title("UMAP Visualization (GNN Batch Norm layer), Predicted labels")
plt.savefig(base_plot_path + "umap_batch_norm_{}_{}_{}.pdf".format(n_neighbors, min_dist, "pred_labels"))
plt.show()

# %%
n_neighbors=20 #10 #5
min_dist=0.8 #0.99 #0.3
metric='correlation'

umap_bn_embed = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(embed_batch_norm)

# Create a DataFrame with UMAP components and labels
data = {"UMAP1": umap_bn_embed[:, 0], "UMAP2": umap_bn_embed[:, 1], "Label": pred_labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9)
plt.title("UMAP Visualization (GNN Batch Norm layer), Predicted labels")
plt.savefig(base_plot_path + "umap_batch_norm_{}_{}_{}.pdf".format(n_neighbors, min_dist, "pred_labels"))
plt.show()

# %%
n_neighbors=20 #5
min_dist=0.8 #0.3
metric='correlation'

umap_conv_embed = umap.UMAP(n_neighbors=n_neighbors,
                       min_dist=min_dist,
                       metric='correlation').fit_transform(embed_conv)

# Create a DataFrame with UMAP components and labels
data = {"UMAP1": umap_conv_embed[:, 0], "UMAP2": umap_conv_embed[:, 1], "Label": true_labels}
df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
sns.scatterplot(x="UMAP1", y="UMAP2", hue="Label", data=df, palette="viridis", s=50, alpha=0.9) #, palette="viridis", s=50, alpha=0.9
plt.title("UMAP Visualization (GNN PNAConv layer), True labels")
plt.savefig(base_plot_path + "umap_conv_{}_{}.pdf".format(n_neighbors, min_dist))
plt.show()

# %%
import pandas as pd
import numpy as np

file_path = base_path + "df_nebit_dnam_features_test.csv"
df_test_data = pd.read_csv(file_path, sep="\t", header=None)
df_test_data
# Out:
#             0    1         2         3         4         5         6   \
# 0     0.966667 -1.0  0.844475  1.186854  1.078528  0.198717  0.420649
# 1     2.942857 -1.0  0.898153  1.204743  0.727866  0.044253  0.312701
# 2     2.045238 -1.0  0.897646  1.166586  0.708893  0.064919  0.430651
# 3     2.090476 -1.0  0.886212  1.242420  0.795989  0.057060  0.256703
# 4     1.245238 -1.0  0.876587  1.141941  0.846118  0.122924  0.314964
# ...        ...  ...       ...       ...       ...       ...       ...
# 2792 -0.109524  1.0  2.998988 -0.510730  0.000003  0.000056  0.978743
# 2793 -0.104762  1.0  2.999188 -0.545478  0.000024  0.000036  0.246064
# 2794 -0.119048  1.0  2.999208 -0.506807  0.000001  0.000087  0.463305
# 2795 -0.111905  1.0  2.998381 -0.523922  0.000006  0.000018  0.567607
# 2796 -0.097619  1.0  2.999682 -0.501268  0.000013  0.000119  0.979235
#
#             7         8         9   ...        78        79        80  \
# 0     0.315654  0.371301  0.265431  ...  0.370463  0.571908  0.439803
# 1     0.229696  0.243923  0.194979  ...  0.366740  0.348679  0.294176
# 2     0.508906  0.430397  0.333302  ...  0.537635  0.501953  0.448602
# 3     0.296823  0.308911  0.218024  ...  0.329951  0.352985  0.345143
# 4     0.250373  0.259187  0.238015  ...  0.417624  0.431051  0.438103
# ...        ...       ...       ...  ...       ...       ...       ...
# 2792  0.975147  0.967003  0.939963  ...  0.952911  0.952860  0.960463
# 2793  0.181775  0.281177  0.396663  ...  0.248957  0.177412  0.475398
# 2794  0.463901  0.399910  0.368827  ...  0.226938  0.287705  0.486991
# 2795  0.181335  0.163493  0.522188  ...  0.551647  0.504781  0.547805
# 2796  0.985307  0.982901  0.983414  ...  0.928106  0.979455  0.990519
#
#             81        82        83        84        85  86  \
# 0     0.560614  0.483471  0.521094  0.464730  0.438450   1
# 1     0.440183  0.340785  0.258195  0.289059  0.283135   1
# 2     0.597685  0.404161  0.400028  0.422716  0.466858   1
# 3     0.440366  0.317415  0.247614  0.334988  0.312502   1
# 4     0.450741  0.332239  0.275716  0.425515  0.470709   1
# ...        ...       ...       ...       ...       ...  ..
# 2792  0.949606  0.954800  0.928092  0.939847  0.948152   5
# 2793  0.510954  0.124151  0.607037  0.478428  0.115471   5
# 2794  0.366356  0.284489  0.517643  0.539067  0.344195   5
# 2795  0.475360  0.552860  0.078884  0.547311  0.186670   5
# 2796  0.984228  0.986848  0.968630  0.920839  0.943231   5
#
#                         87
# 0          cg15694422_MGLL
# 1         cg22644321_TRIB1
# 2         cg20758823_RUNX2
# 3        cg22832271_ARID5B
# 4         cg17776881_MEF2C
# ...                    ...
# 2792       cg05873605_SETX
# 2793     cg01819759_RNF219
# 2794     cg03086067_SH2D4B
# 2795         cg12768975_C3
# 2796  cg01343663_LINC01502
#
# [2797 rows x 88 columns]

# %%
#df_f_name_labels = df_test_data.loc[:, 86:87]
df_labels["pred_labels"] = pred_labels
#df_f_name_labels.columns = ["labels", "features", "pred_labels"]
df_labels
# Out:
#               feature_name  labels  pred_labels
# 0          cg15694422_MGLL       1            5
# 1         cg22644321_TRIB1       1            1
# 2         cg20758823_RUNX2       1            1
# 3        cg22832271_ARID5B       1            1
# 4         cg17776881_MEF2C       1            1
# ...                    ...     ...          ...
# 2792       cg05873605_SETX       5            5
# 2793     cg01819759_RNF219       5            5
# 2794     cg03086067_SH2D4B       5            5
# 2795         cg12768975_C3       5            5
# 2796  cg01343663_LINC01502       5            5
#
# [2797 rows x 3 columns]

# %%
df_seeds = pd.read_csv("data/seed_features_bc.csv", sep="\t", header=None)
df_seeds.columns = ["features", "association_scores"]
df_seeds
# Out:
#                       features  association_scores
# 0              cg15694422_MGLL            0.094113
# 1             cg02116768_FOXK2            0.068692
# 2             cg04582369_ITPR1            0.060345
# 3          cg06490548_C9orf156            0.066583
# 4              cg04498924_AFF1            0.062875
# ..                         ...                 ...
# 192           cg26371957_NINJ2            0.079284
# 193            cg02184558_DUS2            0.062617
# 194          cg13808314_THSD7A            0.070878
# 195          cg05635388_EXOSC9            0.082511
# 196  cg02409829_TCONS_00029157            0.071402
#
# [197 rows x 2 columns]

# %%
# Out:
#       labels              features  pred_labels
# 26         2       cg24442586_FZD6            2
# 27         2      cg03471195_NINJ2            2
# 28         2     cg06411521_SPTLC2            2
# 29         2     cg04790356_ZNF438            2
# 30         2        cg03414898_VCL            2
# ...      ...                   ...          ...
# 1263       2        cg22480835_TNC            2
# 1266       3     cg05661667_ZCCHC7            2
# 1286       3      cg17317764_PDE9A            2
# 1287       2  cg26727928_LINC01422            2
# 1362       3     cg21213111_NUP214            2
#
# [781 rows x 3 columns]

# %%
pred_pos = df_f_name_labels[(df_f_name_labels["labels"].isin([1])) & \
                                    (df_f_name_labels["pred_labels"].isin([1]))]
pred_pos
# Out:
#       labels                   features  pred_labels
# 1          1           cg22644321_TRIB1            1
# 2          1           cg20758823_RUNX2            1
# 3          1          cg22832271_ARID5B            1
# 4          1           cg17776881_MEF2C            1
# 5          1            cg01447281_RERE            1
# ...      ...                        ...          ...
# 774        1          cg15648040_PHF21B            1
# 792        1           cg07647771_USP10            1
# 920        1            cg02184558_DUS2            1
# 953        1           cg25787588_ATP5S            1
# 1351       1  cg02409829_TCONS_00029157            1
#
# [61 rows x 3 columns]

# %%
df_out_genes = pd.read_csv("data/out_genes_bc.csv", sep=" ", header=None)
df_out_genes
# Out:
#            0                    1         2
# 0          0      cg15694422_MGLL  0.094113
# 1          1     cg02116768_FOXK2  0.068692
# 2          2    cg13675051_RNF19A  0.067849
# 3          3     cg22644321_TRIB1  0.062260
# 4          4    cg18881723_SLAMF1  0.062107
# ...      ...                  ...       ...
# 10192  10192  cg23018707_C12orf35  0.000000
# 10193  10193   cg23930101_DENND6A  0.000000
# 10194  10194      cg12047283_SGK1  0.000000
# 10195  10195    cg04225510_CDC123  0.000000
# 10196  10196     cg04225510_NUDT5  0.000000
#
# [10197 rows x 3 columns]

# %%
training_node_ids = pd.read_csv("data/training_node_ids.csv", sep="\t")
training_node_ids
# Out:
#       training_node_ids
# 0                 10155
# 1                  9291
# 2                  1535
# 3                  4121
# 4                  8248
# ...                 ...
# 6826               5734
# 6827               5191
# 6828               5390
# 6829                860
# 6830               7270
#
# [6831 rows x 1 columns]

# %%
all_tr_genes = []
all_tr_probes = []
tr_probes_genes = []

tr_probes_genes = df_out_genes[df_out_genes.iloc[:, 0].isin(training_node_ids["training_node_ids"].tolist())]
tr_probes_genes
# Out:
#            0                    1         2
# 1          1     cg02116768_FOXK2  0.068692
# 2          2    cg13675051_RNF19A  0.067849
# 4          4    cg18881723_SLAMF1  0.062107
# 5          5     cg14173033_FOXK2  0.070052
# 6          6   cg26582754_PHACTR2  0.073266
# ...      ...                  ...       ...
# 10191  10191  cg24067429_C1orf228  0.000000
# 10192  10192  cg23018707_C12orf35  0.000000
# 10193  10193   cg23930101_DENND6A  0.000000
# 10194  10194      cg12047283_SGK1  0.000000
# 10196  10196     cg04225510_NUDT5  0.000000
#
# [6831 rows x 3 columns]

# %%
tr_genes = list()
tr_probes = list()
for i, row in tr_probes_genes.iterrows():
    rvals = row.values[1].split("_")
    tr_probes.append(rvals[0])
    tr_genes.append(rvals[1])

tr_probes_genes["genes"] = tr_genes
tr_probes_genes["probes"] = tr_probes
tr_probes_genes.to_csv("data/tr_probes_genes.csv", sep="\t", index=None)
tr_probes_genes
# Out:
# /tmp/ipykernel_3778/1407122053.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr_probes_genes["genes"] = tr_genes
# /tmp/ipykernel_3778/1407122053.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr_probes_genes["probes"] = tr_probes
#            0                    1         2     genes      probes
# 1          1     cg02116768_FOXK2  0.068692     FOXK2  cg02116768
# 2          2    cg13675051_RNF19A  0.067849    RNF19A  cg13675051
# 4          4    cg18881723_SLAMF1  0.062107    SLAMF1  cg18881723
# 5          5     cg14173033_FOXK2  0.070052     FOXK2  cg14173033
# 6          6   cg26582754_PHACTR2  0.073266   PHACTR2  cg26582754
# ...      ...                  ...       ...       ...         ...
# 10191  10191  cg24067429_C1orf228  0.000000  C1orf228  cg24067429
# 10192  10192  cg23018707_C12orf35  0.000000  C12orf35  cg23018707
# 10193  10193   cg23930101_DENND6A  0.000000   DENND6A  cg23930101
# 10194  10194      cg12047283_SGK1  0.000000      SGK1  cg12047283
# 10196  10196     cg04225510_NUDT5  0.000000     NUDT5  cg04225510
#
# [6831 rows x 5 columns]

# %%
pred_likely_pos = df_f_name_labels[(df_f_name_labels["labels"].isin([2, 3, 4, 5])) & \
                                    (df_f_name_labels["pred_labels"].isin([2]))]
pred_likely_pos
# Out:
#       labels              features  pred_labels
# 26         2       cg24442586_FZD6            2
# 27         2      cg03471195_NINJ2            2
# 28         2     cg06411521_SPTLC2            2
# 29         2     cg04790356_ZNF438            2
# 30         2        cg03414898_VCL            2
# ...      ...                   ...          ...
# 1263       2        cg22480835_TNC            2
# 1266       3     cg05661667_ZCCHC7            2
# 1286       3      cg17317764_PDE9A            2
# 1287       2  cg26727928_LINC01422            2
# 1362       3     cg21213111_NUP214            2
#
# [781 rows x 3 columns]

# %%
tr_genes = list()
tr_probes = list()
for i, row in pred_likely_pos.iterrows():
    rvals = row.values[1].split("_")
    tr_probes.append(rvals[0])
    tr_genes.append(rvals[1])

pred_likely_pos["genes"] = tr_genes
pred_likely_pos["probes"] = tr_probes
pred_likely_pos
# Out:
# /tmp/ipykernel_3778/3859859880.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_likely_pos["genes"] = tr_genes
# /tmp/ipykernel_3778/3859859880.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_likely_pos["probes"] = tr_probes
#       labels              features  pred_labels      genes      probes
# 26         2       cg24442586_FZD6            2       FZD6  cg24442586
# 27         2      cg03471195_NINJ2            2      NINJ2  cg03471195
# 28         2     cg06411521_SPTLC2            2     SPTLC2  cg06411521
# 29         2     cg04790356_ZNF438            2     ZNF438  cg04790356
# 30         2        cg03414898_VCL            2        VCL  cg03414898
# ...      ...                   ...          ...        ...         ...
# 1263       2        cg22480835_TNC            2        TNC  cg22480835
# 1266       3     cg05661667_ZCCHC7            2     ZCCHC7  cg05661667
# 1286       3      cg17317764_PDE9A            2      PDE9A  cg17317764
# 1287       2  cg26727928_LINC01422            2  LINC01422  cg26727928
# 1362       3     cg21213111_NUP214            2     NUP214  cg21213111
#
# [781 rows x 5 columns]

# %%
pred_likely_pos = pred_likely_pos[~pred_likely_pos["genes"].isin(tr_probes_genes["genes"])]
pred_likely_pos = pred_likely_pos[~pred_likely_pos["probes"].isin(tr_probes_genes["probes"])]
pred_likely_pos
# Out:
#       labels              features  pred_labels      genes      probes
# 29         2     cg04790356_ZNF438            2     ZNF438  cg04790356
# 30         2        cg03414898_VCL            2        VCL  cg03414898
# 32         2     cg14422240_FTSJD2            2     FTSJD2  cg14422240
# 33         2    cg03090145_C4orf29            2    C4orf29  cg03090145
# 35         2      cg27391674_AP1B1            2      AP1B1  cg27391674
# ...      ...                   ...          ...        ...         ...
# 1220       2     cg07687276_PRIMA1            2     PRIMA1  cg07687276
# 1221       2       cg00638797_GNB5            2       GNB5  cg00638797
# 1223       2     cg04883656_OGFRL1            2     OGFRL1  cg04883656
# 1263       2        cg22480835_TNC            2        TNC  cg22480835
# 1287       2  cg26727928_LINC01422            2  LINC01422  cg26727928
#
# [427 rows x 5 columns]

# %%
pred_likely_pos.to_csv("data/pred_likely_pos_no_training_genes_probes.csv", index=None, sep="\t")

# %%
test_probe_id_list = list()
for i, row in pred_likely_pos.iterrows():
    r_values = row.values
    name = r_values[1]
    id = df_out_genes[df_out_genes.iloc[:, 1] == name]
    test_probe_id_list.append(id.values[0][0])

# %%
pred_likely_pos["test_probe_ids"] = test_probe_id_list
pred_likely_pos.to_csv("data/pred_likely_pos.csv", sep=",", index=None)
pred_likely_pos
# Out:
# /tmp/ipykernel_3778/583779967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_likely_pos["test_probe_ids"] = test_probe_id_list
#       labels              features  pred_labels  test_probe_ids
# 26         2       cg24442586_FZD6            2              61
# 27         2      cg03471195_NINJ2            2              63
# 28         2     cg06411521_SPTLC2            2              65
# 29         2     cg04790356_ZNF438            2              69
# 30         2        cg03414898_VCL            2              70
# ...      ...                   ...          ...             ...
# 1263       2        cg22480835_TNC            2            4393
# 1266       3     cg05661667_ZCCHC7            2            4397
# 1286       3      cg17317764_PDE9A            2            4502
# 1287       2  cg26727928_LINC01422            2            4505
# 1362       3     cg21213111_NUP214            2            4734
#
# [781 rows x 4 columns]

# %%
#likely_pos_pred_likely_pos = df_f_name_labels[(df_f_name_labels["labels"].isin([2])) | \
                                    #(df_f_name_labels["pred_labels"].isin([2]))]
#likely_pos_pred_likely_pos

# %%
# cg24442586_FZD6 
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8883113/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5248601/

# cg06411521_SPTLC2
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9552870/
# 

# cg04790356_ZNF438
# https://apps.dtic.mil/sti/tr/pdf/ADA566871.pdf
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7889165/

# cg05661667_ZCCHC7
# https://ccsm.uth.edu/PCTfuncDB/gene_search_result.cgi?page1=7&type=quick_search&quick_search=ZCCHC7
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6688494/

# cg00849335_PDE4B
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9582262/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8169683/

# cg03414898_VCL
# https://www.sciencedirect.com/science/article/pii/S0753332221011860
# 

# cg14422240_FTSJD2
# https://www.tandfonline.com/doi/full/10.1080/2162402X.2019.1655964#d1e437
# https://ualcan.path.uab.edu/cgi-bin/TCGAExResultNew2.pl?genenam=FTSJD2&ctype=BRCA
# https://www.life-science-alliance.org/content/1/3/e201800092

# %%
pos_likely_pos_features = pred_likely_pos["features"].tolist()
print(len(pos_likely_pos_features))
df_seeds_as_positive = df_seeds[df_seeds["features"].isin(pos_likely_pos_features)]
df_seeds_as_positive
# Out:
# 691
# Empty DataFrame
# Columns: [features, association_scores]
# Index: []

# %%
np.median(df_seeds_as_positive["association_scores"])
# Out:
# /home/ubuntu/data/miniconda3/envs/nanodiag_biomarker/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/data/miniconda3/envs/nanodiag_biomarker/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
negative_likely_negative = df_f_name_labels[df_f_name_labels["labels"].isin([3,4,5])]
negative_likely_negative
# Out:
#       labels            features  pred_labels
# 285        3    cg00001364_PROX1            3
# 296        3  cg00036599_C1orf54            3
# 297        3     cg00048381_ADAR            3
# 303        3  cg00067058_GPATCH3            2
# 316        3   cg00113315_SLC2A5            3
# ...      ...                 ...          ...
# 2699       5    cg01778345_GDAP2            5
# 2700       5   cg02642404_FAM36A            5
# 2701       5   cg00581848_GPR157            5
# 2702       5    cg05262634_CDCA8            5
# 2703       5   cg03524755_FAM73A            5
#
# [1454 rows x 3 columns]

# %%
negative_likely_negative_features = negative_likely_negative["features"].tolist()
df_seeds_as_negative = df_seeds[df_seeds["features"].isin(negative_likely_negative_features)]
df_seeds_as_negative
# Out:
# Empty DataFrame
# Columns: [features, association_scores]
# Index: []

# %%
# likely positive
df_likely_positive = df_f_name_labels[df_f_name_labels["pred_labels"].isin([1]) & \
                                      df_f_name_labels["labels"].isin([5])]
df_likely_positive, len(df_likely_positive)
# Out:
# (Empty DataFrame
#  Columns: [labels, features, pred_labels]
#  Index: [],
#  0)

# %%
df_likely_positive_features = df_likely_positive["features"].tolist()
len(df_likely_positive_features), df_likely_positive_features[:5]
# Out:
# (0, [])

# %%
df_seed_features = df_seeds["features"].tolist()
len(df_seed_features), df_seed_features[:5]
# Out:
# (1758,
#  ['cg00394221_FCRL1',
#   'cg00755661_CTTNBP2NL',
#   'cg01343097_OR2M1P',
#   'cg01523881_KIF21B',
#   'cg01637011_KIF21B'])

# %%
likely_pos_in_seeds = list(set(df_seed_features).intersection(set(df_likely_positive_features)))
len(likely_pos_in_seeds), likely_pos_in_seeds[:5]
# Out:
# (0, [])
